# %%
#Importing required libraries

import selenium 
import pandas as pd
from selenium import webdriver
import time
from selenium.common.exceptions import NoSuchElementException
import time
import warnings
warnings.filterwarnings('ignore')

# %%
#connecting to the web driver
driver = webdriver.Chrome('chromedriver.exe')

# %%
#opening the yatra.com website
url = 'https://www.yatra.com/'
driver.get(url)

# %%
search_flights = driver.find_element_by_xpath("//input[@class='js_ripple search-btn ']")
search_flights.click()

# %%
#creating empty lists
Airline_Name = []
date_of_journey = []
source = []
destination = []
Departure_time = []
arrival_time = []
duration = []
total_stop = []
price = []
SOURCE= []

# %%
driver.maximize_window()

# %%
#Extracting airlines name
try:
    Name = driver.find_elements_by_xpath("//span[@class='i-b text ellipsis']")
    for i in Name:
        Airline_Name.append(i.text)
        
except NoSuchElementException as e:
    Airline_Name.append("-")
            
#Extracting departure time
try:
    DTime = driver.find_elements_by_xpath("//div[@class='fs-15 bold time']")
    for i in DTime:
        Departure_time.append(i.text)
        
except NoSuchElementException as e:
    Departure_time.append("-")
    
#Extracting arival time
try:
    atime = driver.find_elements_by_xpath("//p[@class='bold fs-15 mb-2 pr time']")
    for i in atime:
        arrival_time.append(i.text)
        
except NoSuchElementException as e:
    arrival_time.append("-")

#Extracting source
try:
    Source = driver.find_elements_by_xpath("//p[@class='fs-10 font-lightgrey no-wrap city ellipsis']")
    for i in Source:
        source.append(i.text)
        
except NoSuchElementException as e:
    source.append("-")
            

#Extracting duration
try:
    Duration = driver.find_elements_by_xpath("//p[@class='fs-12 bold du mb-2']")
    for i in Duration:
        duration.append(i.text)
        
except NoSuchElementException as e:
    duration.append("-")
            
#Extracting stops
try:
    Total_Stops = driver.find_elements_by_xpath("//div[@class=' font-lightgrey fs-10 tipsy i-b fs-10']")
    for i in Total_Stops:
        total_stop.append(i.text)
        
except NoSuchElementException as e:
    total_stop.append("-")
            

#Extracting price of the ticket
try:
    pr = driver.find_elements_by_xpath("//div[@class='i-b tipsy fare-summary-tooltip fs-18']")
    for i in pr:
        price.append(i.text)
        
except NoSuchElementException as e:
    price.append("-")
            

time.sleep(10)

calender = driver.find_element_by_xpath("//p[@class = 'bold font-lightgrey fs-8 mt-2 text-uppercase']")
calender.click()

next_day = driver.find_element_by_xpath("//td[@class=' shown'][1]")
next_day.click()

time.sleep(15)

#Extracting airlines name
try:
    Name = driver.find_elements_by_xpath("//span[@class='i-b text ellipsis']")
    for i in Name:
        Airline_Name.append(i.text)
        
except NoSuchElementException as e:
    Airline_Name.append("-")
            

#Extracting departure time
try:
    DTime = driver.find_elements_by_xpath("//div[@class='fs-15 bold time']")
    for i in DTime:
        Departure_time.append(i.text)
        
except NoSuchElementException as e:
    Departure_time.append("-")
            


#Extracting arival time
try:
    atime = driver.find_elements_by_xpath("//p[@class='bold fs-15 mb-2 pr time']")
    for i in atime:
        arrival_time.append(i.text)
        
except NoSuchElementException as e:
    arrival_time.append("-")
            


#Extracting source
try:
    Source = driver.find_elements_by_xpath("//p[@class='fs-10 font-lightgrey no-wrap city ellipsis']")
    for i in Source:
        source.append(i.text)
        
except NoSuchElementException as e:
    source.append("-")
            


#Extracting duration
try:
    Duration = driver.find_elements_by_xpath("//p[@class='fs-12 bold du mb-2']")
    for i in Duration:
        duration.append(i.text)
        
except NoSuchElementException as e:
    duration.append("-")
            


#Extracting stops
try:
    Total_Stops = driver.find_elements_by_xpath("//div[@class=' font-lightgrey fs-10 tipsy i-b fs-10']")
    for i in Total_Stops:
        total_stop.append(i.text)
        
except NoSuchElementException as e:
    total_stop.append("-")
            


#Extracting price of the ticket
try:
    pr = driver.find_elements_by_xpath("//div[@class='i-b tipsy fare-summary-tooltip fs-18']")
    for i in pr:
        price.append(i.text)
        
except NoSuchElementException as e:
    price.append("-")
    
time.sleep(10)
            
calender = driver.find_element_by_xpath("//p[@class = 'bold font-lightgrey fs-8 mt-2 text-uppercase']")
calender.click()

next_day = driver.find_element_by_xpath("//td[@class=' shown'][2]")
next_day.click()

time.sleep(15)


#Extracting airlines name
try:
    Name = driver.find_elements_by_xpath("//span[@class='i-b text ellipsis']")
    for i in Name:
        Airline_Name.append(i.text)
        
except NoSuchElementException as e:
    Airline_Name.append("-")
            

#Extracting departure time
try:
    DTime = driver.find_elements_by_xpath("//div[@class='fs-15 bold time']")
    for i in DTime:
        Departure_time.append(i.text)
        
except NoSuchElementException as e:
    Departure_time.append("-")
            


#Extracting arival time
try:
    atime = driver.find_elements_by_xpath("//p[@class='bold fs-15 mb-2 pr time']")
    for i in atime:
        arrival_time.append(i.text)
        
except NoSuchElementException as e:
    arrival_time.append("-")
            


#Extracting source
try:
    Source = driver.find_elements_by_xpath("//p[@class='fs-10 font-lightgrey no-wrap city ellipsis']")
    for i in Source:
        source.append(i.text)
        
except NoSuchElementException as e:
    source.append("-")
            


#Extracting duration
try:
    Duration = driver.find_elements_by_xpath("//p[@class='fs-12 bold du mb-2']")
    for i in Duration:
        duration.append(i.text)
        
except NoSuchElementException as e:
    duration.append("-")
            


#Extracting stops
try:
    Total_Stops = driver.find_elements_by_xpath("//div[@class=' font-lightgrey fs-10 tipsy i-b fs-10']")
    for i in Total_Stops:
        total_stop.append(i.text)
        
except NoSuchElementException as e:
    total_stop.append("-")
            


#Extracting price of the ticket
try:
    pr = driver.find_elements_by_xpath("//div[@class='i-b tipsy fare-summary-tooltip fs-18']")
    for i in pr:
        price.append(i.text)
        
except NoSuchElementException as e:
    price.append("-")

# %%
#changing the location of departure
pune = driver.find_element_by_xpath("//input[@class = 'fs-16 bold ng-touched ng-dirty ng-valid-parse ng-invalid ng-invalid-required ellipsis full-width ng-pristine ng-valid ng-not-empty ng-valid-required']")
pune.clear()

# %%
pune.send_keys('Pune')

# %%
#search again
search_again = driver.find_element_by_xpath("//div[@class = 'input-holder pb-2']")
search_again.click()

# %%
#Extracting airlines name
try:
    Name = driver.find_elements_by_xpath("//span[@class='i-b text ellipsis']")
    for i in Name:
        Airline_Name.append(i.text)
        
except NoSuchElementException as e:
    Airline_Name.append("-")
            
#Extracting departure time
try:
    DTime = driver.find_elements_by_xpath("//div[@class='fs-15 bold time']")
    for i in DTime:
        Departure_time.append(i.text)
        
except NoSuchElementException as e:
    Departure_time.append("-")
    
#Extracting arival time
try:
    atime = driver.find_elements_by_xpath("//p[@class='bold fs-15 mb-2 pr time']")
    for i in atime:
        arrival_time.append(i.text)
        
except NoSuchElementException as e:
    arrival_time.append("-")

#Extracting source
try:
    Source = driver.find_elements_by_xpath("//p[@class='fs-10 font-lightgrey no-wrap city ellipsis']")
    for i in Source:
        source.append(i.text)
        
except NoSuchElementException as e:
    source.append("-")
            

#Extracting duration
try:
    Duration = driver.find_elements_by_xpath("//p[@class='fs-12 bold du mb-2']")
    for i in Duration:
        duration.append(i.text)
        
except NoSuchElementException as e:
    duration.append("-")
            
#Extracting stops
try:
    Total_Stops = driver.find_elements_by_xpath("//div[@class=' font-lightgrey fs-10 tipsy i-b fs-10']")
    for i in Total_Stops:
        total_stop.append(i.text)
        
except NoSuchElementException as e:
    total_stop.append("-")
            

#Extracting price of the ticket
try:
    pr = driver.find_elements_by_xpath("//div[@class='i-b tipsy fare-summary-tooltip fs-18']")
    for i in pr:
        price.append(i.text)
        
except NoSuchElementException as e:
    price.append("-")

# %%
calender = driver.find_element_by_xpath("//p[@class = 'bold font-lightgrey fs-8 mt-2 text-uppercase']")
calender.click()

# %%
next_day = driver.find_element_by_xpath("//td[@class=' shown'][1]")
next_day.click()

# %%
#Extracting airlines name
try:
    Name = driver.find_elements_by_xpath("//span[@class='i-b text ellipsis']")
    for i in Name:
        Airline_Name.append(i.text)
        
except NoSuchElementException as e:
    Airline_Name.append("-")
            

#Extracting departure time
try:
    DTime = driver.find_elements_by_xpath("//div[@class='fs-15 bold time']")
    for i in DTime:
        Departure_time.append(i.text)
        
except NoSuchElementException as e:
    Departure_time.append("-")
            


#Extracting arival time
try:
    atime = driver.find_elements_by_xpath("//p[@class='bold fs-15 mb-2 pr time']")
    for i in atime:
        arrival_time.append(i.text)
        
except NoSuchElementException as e:
    arrival_time.append("-")
            


#Extracting source
try:
    Source = driver.find_elements_by_xpath("//p[@class='fs-10 font-lightgrey no-wrap city ellipsis']")
    for i in Source:
        source.append(i.text)
        
except NoSuchElementException as e:
    source.append("-")
            


#Extracting duration
try:
    Duration = driver.find_elements_by_xpath("//p[@class='fs-12 bold du mb-2']")
    for i in Duration:
        duration.append(i.text)
        
except NoSuchElementException as e:
    duration.append("-")
            


#Extracting stops
try:
    Total_Stops = driver.find_elements_by_xpath("//div[@class=' font-lightgrey fs-10 tipsy i-b fs-10']")
    for i in Total_Stops:
        total_stop.append(i.text)
        
except NoSuchElementException as e:
    total_stop.append("-")
            


#Extracting price of the ticket
try:
    pr = driver.find_elements_by_xpath("//div[@class='i-b tipsy fare-summary-tooltip fs-18']")
    for i in pr:
        price.append(i.text)
        
except NoSuchElementException as e:
    price.append("-")

# %%
calender = driver.find_element_by_xpath("//p[@class = 'bold font-lightgrey fs-8 mt-2 text-uppercase']")
calender.click()

# %%
next_day = driver.find_element_by_xpath("//td[@class=' shown'][2]")
next_day.click()

# %%
#Extracting airlines name
try:
    Name = driver.find_elements_by_xpath("//span[@class='i-b text ellipsis']")
    for i in Name:
        Airline_Name.append(i.text)
        
except NoSuchElementException as e:
    Airline_Name.append("-")
            

#Extracting departure time
try:
    DTime = driver.find_elements_by_xpath("//div[@class='fs-15 bold time']")
    for i in DTime:
        Departure_time.append(i.text)
        
except NoSuchElementException as e:
    Departure_time.append("-")
            


#Extracting arival time
try:
    atime = driver.find_elements_by_xpath("//p[@class='bold fs-15 mb-2 pr time']")
    for i in atime:
        arrival_time.append(i.text)
        
except NoSuchElementException as e:
    arrival_time.append("-")
            


#Extracting source
try:
    Source = driver.find_elements_by_xpath("//p[@class='fs-10 font-lightgrey no-wrap city ellipsis']")
    for i in Source:
        source.append(i.text)
        
except NoSuchElementException as e:
    source.append("-")
            


#Extracting duration
try:
    Duration = driver.find_elements_by_xpath("//p[@class='fs-12 bold du mb-2']")
    for i in Duration:
        duration.append(i.text)
        
except NoSuchElementException as e:
    duration.append("-")
            


#Extracting stops
try:
    Total_Stops = driver.find_elements_by_xpath("//div[@class=' font-lightgrey fs-10 tipsy i-b fs-10']")
    for i in Total_Stops:
        total_stop.append(i.text)
        
except NoSuchElementException as e:
    total_stop.append("-")
            


#Extracting price of the ticket
try:
    pr = driver.find_elements_by_xpath("//div[@class='i-b tipsy fare-summary-tooltip fs-18']")
    for i in pr:
        price.append(i.text)
        
except NoSuchElementException as e:
    price.append("-")

# %%
#changing the location of arrival
arrival = driver.find_element_by_xpath("//input[@class = 'fs-16 bold ng-touched ng-dirty ellipsis full-width ng-not-empty ng-valid ng-valid-required']")
arrival.clear()

# %%
arrival.send_keys('new delhi')

# %%
#search again
search_again = driver.find_element_by_xpath("//div[@class = 'input-holder pb-2']")
search_again.click()

# %%
#Extracting airlines name
try:
    Name = driver.find_elements_by_xpath("//span[@class='i-b text ellipsis']")
    for i in Name:
        Airline_Name.append(i.text)
        
except NoSuchElementException as e:
    Airline_Name.append("-")
            
#Extracting departure time
try:
    DTime = driver.find_elements_by_xpath("//div[@class='fs-15 bold time']")
    for i in DTime:
        Departure_time.append(i.text)
        
except NoSuchElementException as e:
    Departure_time.append("-")
    
#Extracting arival time
try:
    atime = driver.find_elements_by_xpath("//p[@class='bold fs-15 mb-2 pr time']")
    for i in atime:
        arrival_time.append(i.text)
        
except NoSuchElementException as e:
    arrival_time.append("-")

#Extracting source
try:
    Source = driver.find_elements_by_xpath("//p[@class='fs-10 font-lightgrey no-wrap city ellipsis']")
    for i in Source:
        source.append(i.text)
        
except NoSuchElementException as e:
    source.append("-")
            

#Extracting duration
try:
    Duration = driver.find_elements_by_xpath("//p[@class='fs-12 bold du mb-2']")
    for i in Duration:
        duration.append(i.text)
        
except NoSuchElementException as e:
    duration.append("-")
            
#Extracting stops
try:
    Total_Stops = driver.find_elements_by_xpath("//div[@class=' font-lightgrey fs-10 tipsy i-b fs-10']")
    for i in Total_Stops:
        total_stop.append(i.text)
        
except NoSuchElementException as e:
    total_stop.append("-")
            

#Extracting price of the ticket
try:
    pr = driver.find_elements_by_xpath("//div[@class='i-b tipsy fare-summary-tooltip fs-18']")
    for i in pr:
        price.append(i.text)
        
except NoSuchElementException as e:
    price.append("-")

# %%
calender = driver.find_element_by_xpath("//p[@class = 'bold font-lightgrey fs-8 mt-2 text-uppercase']")
calender.click()

# %%
next_day = driver.find_element_by_xpath("//td[@class=' shown'][1]")
next_day.click()

# %%
#Extracting airlines name
try:
    Name = driver.find_elements_by_xpath("//span[@class='i-b text ellipsis']")
    for i in Name:
        Airline_Name.append(i.text)
        
except NoSuchElementException as e:
    Airline_Name.append("-")
            
#Extracting departure time
try:
    DTime = driver.find_elements_by_xpath("//div[@class='fs-15 bold time']")
    for i in DTime:
        Departure_time.append(i.text)
        
except NoSuchElementException as e:
    Departure_time.append("-")
    
#Extracting arival time
try:
    atime = driver.find_elements_by_xpath("//p[@class='bold fs-15 mb-2 pr time']")
    for i in atime:
        arrival_time.append(i.text)
        
except NoSuchElementException as e:
    arrival_time.append("-")

#Extracting source
try:
    Source = driver.find_elements_by_xpath("//p[@class='fs-10 font-lightgrey no-wrap city ellipsis']")
    for i in Source:
        source.append(i.text)
        
except NoSuchElementException as e:
    source.append("-")
            

#Extracting duration
try:
    Duration = driver.find_elements_by_xpath("//p[@class='fs-12 bold du mb-2']")
    for i in Duration:
        duration.append(i.text)
        
except NoSuchElementException as e:
    duration.append("-")
            
#Extracting stops
try:
    Total_Stops = driver.find_elements_by_xpath("//div[@class=' font-lightgrey fs-10 tipsy i-b fs-10']")
    for i in Total_Stops:
        total_stop.append(i.text)
        
except NoSuchElementException as e:
    total_stop.append("-")
            

#Extracting price of the ticket
try:
    pr = driver.find_elements_by_xpath("//div[@class='i-b tipsy fare-summary-tooltip fs-18']")
    for i in pr:
        price.append(i.text)
        
except NoSuchElementException as e:
    price.append("-")

# %%
calender = driver.find_element_by_xpath("//p[@class = 'bold font-lightgrey fs-8 mt-2 text-uppercase']")
calender.click()

# %%
next_day = driver.find_element_by_xpath("//td[@class=' shown'][2]")
next_day.click()

# %%
#Extracting airlines name
try:
    Name = driver.find_elements_by_xpath("//span[@class='i-b text ellipsis']")
    for i in Name:
        Airline_Name.append(i.text)
        
except NoSuchElementException as e:
    Airline_Name.append("-")
            
#Extracting departure time
try:
    DTime = driver.find_elements_by_xpath("//div[@class='fs-15 bold time']")
    for i in DTime:
        Departure_time.append(i.text)
        
except NoSuchElementException as e:
    Departure_time.append("-")
    
#Extracting arival time
try:
    atime = driver.find_elements_by_xpath("//p[@class='bold fs-15 mb-2 pr time']")
    for i in atime:
        arrival_time.append(i.text)
        
except NoSuchElementException as e:
    arrival_time.append("-")

#Extracting source
try:
    Source = driver.find_elements_by_xpath("//p[@class='fs-10 font-lightgrey no-wrap city ellipsis']")
    for i in Source:
        source.append(i.text)
        
except NoSuchElementException as e:
    source.append("-")
            

#Extracting duration
try:
    Duration = driver.find_elements_by_xpath("//p[@class='fs-12 bold du mb-2']")
    for i in Duration:
        duration.append(i.text)
        
except NoSuchElementException as e:
    duration.append("-")
            
#Extracting stops
try:
    Total_Stops = driver.find_elements_by_xpath("//div[@class=' font-lightgrey fs-10 tipsy i-b fs-10']")
    for i in Total_Stops:
        total_stop.append(i.text)
        
except NoSuchElementException as e:
    total_stop.append("-")
            

#Extracting price of the ticket
try:
    pr = driver.find_elements_by_xpath("//div[@class='i-b tipsy fare-summary-tooltip fs-18']")
    for i in pr:
        price.append(i.text)
        
except NoSuchElementException as e:
    price.append("-")

# %%
bang = driver.find_element_by_xpath("//input[@class = 'fs-16 bold ng-touched ng-dirty ng-valid-parse ng-invalid ng-invalid-required ellipsis full-width ng-pristine ng-valid ng-not-empty ng-valid-required']")
bang.clear()

# %%
bang.send_keys('Bangalore')

# %%
#search again
search_again = driver.find_element_by_xpath("//div[@class = 'input-holder pb-2']")
search_again.click()

# %%
#Extracting airlines name
try:
    Name = driver.find_elements_by_xpath("//span[@class='i-b text ellipsis']")
    for i in Name:
        Airline_Name.append(i.text)
        
except NoSuchElementException as e:
    Airline_Name.append("-")
            
#Extracting departure time
try:
    DTime = driver.find_elements_by_xpath("//div[@class='fs-15 bold time']")
    for i in DTime:
        Departure_time.append(i.text)
        
except NoSuchElementException as e:
    Departure_time.append("-")
    
#Extracting arival time
try:
    atime = driver.find_elements_by_xpath("//p[@class='bold fs-15 mb-2 pr time']")
    for i in atime:
        arrival_time.append(i.text)
        
except NoSuchElementException as e:
    arrival_time.append("-")

#Extracting source
try:
    Source = driver.find_elements_by_xpath("//p[@class='fs-10 font-lightgrey no-wrap city ellipsis']")
    for i in Source:
        source.append(i.text)
        
except NoSuchElementException as e:
    source.append("-")
            

#Extracting duration
try:
    Duration = driver.find_elements_by_xpath("//p[@class='fs-12 bold du mb-2']")
    for i in Duration:
        duration.append(i.text)
        
except NoSuchElementException as e:
    duration.append("-")
            
#Extracting stops
try:
    Total_Stops = driver.find_elements_by_xpath("//div[@class=' font-lightgrey fs-10 tipsy i-b fs-10']")
    for i in Total_Stops:
        total_stop.append(i.text)
        
except NoSuchElementException as e:
    total_stop.append("-")
            

#Extracting price of the ticket
try:
    pr = driver.find_elements_by_xpath("//div[@class='i-b tipsy fare-summary-tooltip fs-18']")
    for i in pr:
        price.append(i.text)
        
except NoSuchElementException as e:
    price.append("-")

# %%
#show calender 
calender = driver.find_element_by_xpath("//p[@class = 'bold font-lightgrey fs-8 mt-2 text-uppercase']")
calender.click()

# %%
next_day = driver.find_element_by_xpath("//td[@class=' shown'][1]")
next_day.click()

# %%
#Extracting airlines name
try:
    Name = driver.find_elements_by_xpath("//span[@class='i-b text ellipsis']")
    for i in Name:
        Airline_Name.append(i.text)
        
except NoSuchElementException as e:
    Airline_Name.append("-")
            
#Extracting departure time
try:
    DTime = driver.find_elements_by_xpath("//div[@class='fs-15 bold time']")
    for i in DTime:
        Departure_time.append(i.text)
        
except NoSuchElementException as e:
    Departure_time.append("-")
    
#Extracting arival time
try:
    atime = driver.find_elements_by_xpath("//p[@class='bold fs-15 mb-2 pr time']")
    for i in atime:
        arrival_time.append(i.text)
        
except NoSuchElementException as e:
    arrival_time.append("-")

#Extracting source
try:
    Source = driver.find_elements_by_xpath("//p[@class='fs-10 font-lightgrey no-wrap city ellipsis']")
    for i in Source:
        source.append(i.text)
        
except NoSuchElementException as e:
    source.append("-")
            

#Extracting duration
try:
    Duration = driver.find_elements_by_xpath("//p[@class='fs-12 bold du mb-2']")
    for i in Duration:
        duration.append(i.text)
        
except NoSuchElementException as e:
    duration.append("-")
            
#Extracting stops
try:
    Total_Stops = driver.find_elements_by_xpath("//div[@class=' font-lightgrey fs-10 tipsy i-b fs-10']")
    for i in Total_Stops:
        total_stop.append(i.text)
        
except NoSuchElementException as e:
    total_stop.append("-")
            

#Extracting price of the ticket
try:
    pr = driver.find_elements_by_xpath("//div[@class='i-b tipsy fare-summary-tooltip fs-18']")
    for i in pr:
        price.append(i.text)
        
except NoSuchElementException as e:
    price.append("-")

# %%
calender = driver.find_element_by_xpath("//p[@class = 'bold font-lightgrey fs-8 mt-2 text-uppercase']")
calender.click()

next_day = driver.find_element_by_xpath("//td[@class=' shown'][2]")
next_day.click()

# %%
#Extracting airlines name
try:
    Name = driver.find_elements_by_xpath("//span[@class='i-b text ellipsis']")
    for i in Name:
        Airline_Name.append(i.text)
        
except NoSuchElementException as e:
    Airline_Name.append("-")
            
#Extracting departure time
try:
    DTime = driver.find_elements_by_xpath("//div[@class='fs-15 bold time']")
    for i in DTime:
        Departure_time.append(i.text)
        
except NoSuchElementException as e:
    Departure_time.append("-")
    
#Extracting arival time
try:
    atime = driver.find_elements_by_xpath("//p[@class='bold fs-15 mb-2 pr time']")
    for i in atime:
        arrival_time.append(i.text)
        
except NoSuchElementException as e:
    arrival_time.append("-")

#Extracting source
try:
    Source = driver.find_elements_by_xpath("//p[@class='fs-10 font-lightgrey no-wrap city ellipsis']")
    for i in Source:
        source.append(i.text)
        
except NoSuchElementException as e:
    source.append("-")
            

#Extracting duration
try:
    Duration = driver.find_elements_by_xpath("//p[@class='fs-12 bold du mb-2']")
    for i in Duration:
        duration.append(i.text)
        
except NoSuchElementException as e:
    duration.append("-")
            
#Extracting stops
try:
    Total_Stops = driver.find_elements_by_xpath("//div[@class=' font-lightgrey fs-10 tipsy i-b fs-10']")
    for i in Total_Stops:
        total_stop.append(i.text)
        
except NoSuchElementException as e:
    total_stop.append("-")
            

#Extracting price of the ticket
try:
    pr = driver.find_elements_by_xpath("//div[@class='i-b tipsy fare-summary-tooltip fs-18']")
    for i in pr:
        price.append(i.text)
        
except NoSuchElementException as e:
    price.append("-")

# %%
chen = driver.find_element_by_xpath("//input[@class = 'fs-16 bold ng-touched ng-dirty ng-invalid ng-invalid-required ellipsis full-width ng-pristine ng-valid ng-not-empty ng-valid-required']")
chen.clear()

# %%
chen.send_keys('chennai')

# %%
#search again
search_again = driver.find_element_by_xpath("//div[@class = 'input-holder pb-2']")
search_again.click()

# %%
#Extracting airlines name
try:
    Name = driver.find_elements_by_xpath("//span[@class='i-b text ellipsis']")
    for i in Name:
        Airline_Name.append(i.text)
        
except NoSuchElementException as e:
    Airline_Name.append("-")
            
#Extracting departure time
try:
    DTime = driver.find_elements_by_xpath("//div[@class='fs-15 bold time']")
    for i in DTime:
        Departure_time.append(i.text)
        
except NoSuchElementException as e:
    Departure_time.append("-")
    
#Extracting arival time
try:
    atime = driver.find_elements_by_xpath("//p[@class='bold fs-15 mb-2 pr time']")
    for i in atime:
        arrival_time.append(i.text)
        
except NoSuchElementException as e:
    arrival_time.append("-")

#Extracting source
try:
    Source = driver.find_elements_by_xpath("//p[@class='fs-10 font-lightgrey no-wrap city ellipsis']")
    for i in Source:
        source.append(i.text)
        
except NoSuchElementException as e:
    source.append("-")
            

#Extracting duration
try:
    Duration = driver.find_elements_by_xpath("//p[@class='fs-12 bold du mb-2']")
    for i in Duration:
        duration.append(i.text)
        
except NoSuchElementException as e:
    duration.append("-")
            
#Extracting stops
try:
    Total_Stops = driver.find_elements_by_xpath("//div[@class=' font-lightgrey fs-10 tipsy i-b fs-10']")
    for i in Total_Stops:
        total_stop.append(i.text)
        
except NoSuchElementException as e:
    total_stop.append("-")
            

#Extracting price of the ticket
try:
    pr = driver.find_elements_by_xpath("//div[@class='i-b tipsy fare-summary-tooltip fs-18']")
    for i in pr:
        price.append(i.text)
        
except NoSuchElementException as e:
    price.append("-")

# %%
#show calender 
calender = driver.find_element_by_xpath("//p[@class = 'bold font-lightgrey fs-8 mt-2 text-uppercase']")
calender.click()

next_day = driver.find_element_by_xpath("//td[@class=' shown'][1]")
next_day.click()

# %%
#Extracting airlines name
try:
    Name = driver.find_elements_by_xpath("//span[@class='i-b text ellipsis']")
    for i in Name:
        Airline_Name.append(i.text)
        
except NoSuchElementException as e:
    Airline_Name.append("-")
            
#Extracting departure time
try:
    DTime = driver.find_elements_by_xpath("//div[@class='fs-15 bold time']")
    for i in DTime:
        Departure_time.append(i.text)
        
except NoSuchElementException as e:
    Departure_time.append("-")
    
#Extracting arival time
try:
    atime = driver.find_elements_by_xpath("//p[@class='bold fs-15 mb-2 pr time']")
    for i in atime:
        arrival_time.append(i.text)
        
except NoSuchElementException as e:
    arrival_time.append("-")

#Extracting source
try:
    Source = driver.find_elements_by_xpath("//p[@class='fs-10 font-lightgrey no-wrap city ellipsis']")
    for i in Source:
        source.append(i.text)
        
except NoSuchElementException as e:
    source.append("-")
            

#Extracting duration
try:
    Duration = driver.find_elements_by_xpath("//p[@class='fs-12 bold du mb-2']")
    for i in Duration:
        duration.append(i.text)
        
except NoSuchElementException as e:
    duration.append("-")
            
#Extracting stops
try:
    Total_Stops = driver.find_elements_by_xpath("//div[@class=' font-lightgrey fs-10 tipsy i-b fs-10']")
    for i in Total_Stops:
        total_stop.append(i.text)
        
except NoSuchElementException as e:
    total_stop.append("-")
            

#Extracting price of the ticket
try:
    pr = driver.find_elements_by_xpath("//div[@class='i-b tipsy fare-summary-tooltip fs-18']")
    for i in pr:
        price.append(i.text)
        
except NoSuchElementException as e:
    price.append("-")

# %%
#show calender 
calender = driver.find_element_by_xpath("//p[@class = 'bold font-lightgrey fs-8 mt-2 text-uppercase']")
calender.click()

next_day = driver.find_element_by_xpath("//td[@class=' shown'][2]")
next_day.click()

# %%
#Extracting airlines name
try:
    Name = driver.find_elements_by_xpath("//span[@class='i-b text ellipsis']")
    for i in Name:
        Airline_Name.append(i.text)
        
except NoSuchElementException as e:
    Airline_Name.append("-")
            
#Extracting departure time
try:
    DTime = driver.find_elements_by_xpath("//div[@class='fs-15 bold time']")
    for i in DTime:
        Departure_time.append(i.text)
        
except NoSuchElementException as e:
    Departure_time.append("-")
    
#Extracting arival time
try:
    atime = driver.find_elements_by_xpath("//p[@class='bold fs-15 mb-2 pr time']")
    for i in atime:
        arrival_time.append(i.text)
        
except NoSuchElementException as e:
    arrival_time.append("-")

#Extracting source
try:
    Source = driver.find_elements_by_xpath("//p[@class='fs-10 font-lightgrey no-wrap city ellipsis']")
    for i in Source:
        source.append(i.text)
        
except NoSuchElementException as e:
    source.append("-")
            

#Extracting duration
try:
    Duration = driver.find_elements_by_xpath("//p[@class='fs-12 bold du mb-2']")
    for i in Duration:
        duration.append(i.text)
        
except NoSuchElementException as e:
    duration.append("-")
            
#Extracting stops
try:
    Total_Stops = driver.find_elements_by_xpath("//div[@class=' font-lightgrey fs-10 tipsy i-b fs-10']")
    for i in Total_Stops:
        total_stop.append(i.text)
        
except NoSuchElementException as e:
    total_stop.append("-")
            

#Extracting price of the ticket
try:
    pr = driver.find_elements_by_xpath("//div[@class='i-b tipsy fare-summary-tooltip fs-18']")
    for i in pr:
        price.append(i.text)
        
except NoSuchElementException as e:
    price.append("-")

# %%
goa = driver.find_element_by_xpath("//input[@class = 'fs-16 bold ng-touched ng-dirty ng-invalid ng-invalid-required ellipsis full-width ng-pristine ng-valid ng-not-empty ng-valid-required']")
goa.clear()

goa.send_keys('goa')

# %%
#search again
search_again = driver.find_element_by_xpath("//div[@class = 'input-holder pb-2']")
search_again.click()

# %%
#Extracting airlines name
try:
    Name = driver.find_elements_by_xpath("//span[@class='i-b text ellipsis']")
    for i in Name:
        Airline_Name.append(i.text)
        
except NoSuchElementException as e:
    Airline_Name.append("-")
            
#Extracting departure time
try:
    DTime = driver.find_elements_by_xpath("//div[@class='fs-15 bold time']")
    for i in DTime:
        Departure_time.append(i.text)
        
except NoSuchElementException as e:
    Departure_time.append("-")
    
#Extracting arival time
try:
    atime = driver.find_elements_by_xpath("//p[@class='bold fs-15 mb-2 pr time']")
    for i in atime:
        arrival_time.append(i.text)
        
except NoSuchElementException as e:
    arrival_time.append("-")

#Extracting source
try:
    Source = driver.find_elements_by_xpath("//p[@class='fs-10 font-lightgrey no-wrap city ellipsis']")
    for i in Source:
        source.append(i.text)
        
except NoSuchElementException as e:
    source.append("-")
            

#Extracting duration
try:
    Duration = driver.find_elements_by_xpath("//p[@class='fs-12 bold du mb-2']")
    for i in Duration:
        duration.append(i.text)
        
except NoSuchElementException as e:
    duration.append("-")
            
#Extracting stops
try:
    Total_Stops = driver.find_elements_by_xpath("//div[@class=' font-lightgrey fs-10 tipsy i-b fs-10']")
    for i in Total_Stops:
        total_stop.append(i.text)
        
except NoSuchElementException as e:
    total_stop.append("-")
            

#Extracting price of the ticket
try:
    pr = driver.find_elements_by_xpath("//div[@class='i-b tipsy fare-summary-tooltip fs-18']")
    for i in pr:
        price.append(i.text)
        
except NoSuchElementException as e:
    price.append("-")

# %%
#show calender 
calender = driver.find_element_by_xpath("//p[@class = 'bold font-lightgrey fs-8 mt-2 text-uppercase']")
calender.click()

next_day = driver.find_element_by_xpath("//td[@class=' shown'][1]")
next_day.click()

# %%
#Extracting airlines name
try:
    Name = driver.find_elements_by_xpath("//span[@class='i-b text ellipsis']")
    for i in Name:
        Airline_Name.append(i.text)
        
except NoSuchElementException as e:
    Airline_Name.append("-")
            
#Extracting departure time
try:
    DTime = driver.find_elements_by_xpath("//div[@class='fs-15 bold time']")
    for i in DTime:
        Departure_time.append(i.text)
        
except NoSuchElementException as e:
    Departure_time.append("-")
    
#Extracting arival time
try:
    atime = driver.find_elements_by_xpath("//p[@class='bold fs-15 mb-2 pr time']")
    for i in atime:
        arrival_time.append(i.text)
        
except NoSuchElementException as e:
    arrival_time.append("-")

#Extracting source
try:
    Source = driver.find_elements_by_xpath("//p[@class='fs-10 font-lightgrey no-wrap city ellipsis']")
    for i in Source:
        source.append(i.text)
        
except NoSuchElementException as e:
    source.append("-")
            

#Extracting duration
try:
    Duration = driver.find_elements_by_xpath("//p[@class='fs-12 bold du mb-2']")
    for i in Duration:
        duration.append(i.text)
        
except NoSuchElementException as e:
    duration.append("-")
            
#Extracting stops
try:
    Total_Stops = driver.find_elements_by_xpath("//div[@class=' font-lightgrey fs-10 tipsy i-b fs-10']")
    for i in Total_Stops:
        total_stop.append(i.text)
        
except NoSuchElementException as e:
    total_stop.append("-")
            

#Extracting price of the ticket
try:
    pr = driver.find_elements_by_xpath("//div[@class='i-b tipsy fare-summary-tooltip fs-18']")
    for i in pr:
        price.append(i.text)
        
except NoSuchElementException as e:
    price.append("-")

# %%
#show calender 
calender = driver.find_element_by_xpath("//p[@class = 'bold font-lightgrey fs-8 mt-2 text-uppercase']")
calender.click()

next_day = driver.find_element_by_xpath("//td[@class=' shown'][2]")
next_day.click()

# %%
#Extracting airlines name
try:
    Name = driver.find_elements_by_xpath("//span[@class='i-b text ellipsis']")
    for i in Name:
        Airline_Name.append(i.text)
        
except NoSuchElementException as e:
    Airline_Name.append("-")
            
#Extracting departure time
try:
    DTime = driver.find_elements_by_xpath("//div[@class='fs-15 bold time']")
    for i in DTime:
        Departure_time.append(i.text)
        
except NoSuchElementException as e:
    Departure_time.append("-")
    
#Extracting arival time
try:
    atime = driver.find_elements_by_xpath("//p[@class='bold fs-15 mb-2 pr time']")
    for i in atime:
        arrival_time.append(i.text)
        
except NoSuchElementException as e:
    arrival_time.append("-")

#Extracting source
try:
    Source = driver.find_elements_by_xpath("//p[@class='fs-10 font-lightgrey no-wrap city ellipsis']")
    for i in Source:
        source.append(i.text)
        
except NoSuchElementException as e:
    source.append("-")
            

#Extracting duration
try:
    Duration = driver.find_elements_by_xpath("//p[@class='fs-12 bold du mb-2']")
    for i in Duration:
        duration.append(i.text)
        
except NoSuchElementException as e:
    duration.append("-")
            
#Extracting stops
try:
    Total_Stops = driver.find_elements_by_xpath("//div[@class=' font-lightgrey fs-10 tipsy i-b fs-10']")
    for i in Total_Stops:
        total_stop.append(i.text)
        
except NoSuchElementException as e:
    total_stop.append("-")
            

#Extracting price of the ticket
try:
    pr = driver.find_elements_by_xpath("//div[@class='i-b tipsy fare-summary-tooltip fs-18']")
    for i in pr:
        price.append(i.text)
        
except NoSuchElementException as e:
    price.append("-")

# %%
hyb = driver.find_element_by_xpath("//input[@class = 'fs-16 bold ng-touched ng-dirty ng-valid-parse ng-invalid ng-invalid-required ellipsis full-width ng-pristine ng-valid ng-not-empty ng-valid-required']")
hyb.clear()

hyb.send_keys('Hydrabad')

# %%
#search again
search_again = driver.find_element_by_xpath("//div[@class = 'input-holder pb-2']")
search_again.click()

# %%
#Extracting airlines name
try:
    Name = driver.find_elements_by_xpath("//span[@class='i-b text ellipsis']")
    for i in Name:
        Airline_Name.append(i.text)
        
except NoSuchElementException as e:
    Airline_Name.append("-")
            
#Extracting departure time
try:
    DTime = driver.find_elements_by_xpath("//div[@class='fs-15 bold time']")
    for i in DTime:
        Departure_time.append(i.text)
        
except NoSuchElementException as e:
    Departure_time.append("-")
    
#Extracting arival time
try:
    atime = driver.find_elements_by_xpath("//p[@class='bold fs-15 mb-2 pr time']")
    for i in atime:
        arrival_time.append(i.text)
        
except NoSuchElementException as e:
    arrival_time.append("-")

#Extracting source
try:
    Source = driver.find_elements_by_xpath("//p[@class='fs-10 font-lightgrey no-wrap city ellipsis']")
    for i in Source:
        source.append(i.text)
        
except NoSuchElementException as e:
    source.append("-")
            

#Extracting duration
try:
    Duration = driver.find_elements_by_xpath("//p[@class='fs-12 bold du mb-2']")
    for i in Duration:
        duration.append(i.text)
        
except NoSuchElementException as e:
    duration.append("-")
            
#Extracting stops
try:
    Total_Stops = driver.find_elements_by_xpath("//div[@class=' font-lightgrey fs-10 tipsy i-b fs-10']")
    for i in Total_Stops:
        total_stop.append(i.text)
        
except NoSuchElementException as e:
    total_stop.append("-")
            

#Extracting price of the ticket
try:
    pr = driver.find_elements_by_xpath("//div[@class='i-b tipsy fare-summary-tooltip fs-18']")
    for i in pr:
        price.append(i.text)
        
except NoSuchElementException as e:
    price.append("-")

# %%
#show calender 
calender = driver.find_element_by_xpath("//p[@class = 'bold font-lightgrey fs-8 mt-2 text-uppercase']")
calender.click()

next_day = driver.find_element_by_xpath("//td[@class=' shown'][1]")
next_day.click()

# %%
#Extracting airlines name
try:
    Name = driver.find_elements_by_xpath("//span[@class='i-b text ellipsis']")
    for i in Name:
        Airline_Name.append(i.text)
        
except NoSuchElementException as e:
    Airline_Name.append("-")
            
#Extracting departure time
try:
    DTime = driver.find_elements_by_xpath("//div[@class='fs-15 bold time']")
    for i in DTime:
        Departure_time.append(i.text)
        
except NoSuchElementException as e:
    Departure_time.append("-")
    
#Extracting arival time
try:
    atime = driver.find_elements_by_xpath("//p[@class='bold fs-15 mb-2 pr time']")
    for i in atime:
        arrival_time.append(i.text)
        
except NoSuchElementException as e:
    arrival_time.append("-")

#Extracting source
try:
    Source = driver.find_elements_by_xpath("//p[@class='fs-10 font-lightgrey no-wrap city ellipsis']")
    for i in Source:
        source.append(i.text)
        
except NoSuchElementException as e:
    source.append("-")
            

#Extracting duration
try:
    Duration = driver.find_elements_by_xpath("//p[@class='fs-12 bold du mb-2']")
    for i in Duration:
        duration.append(i.text)
        
except NoSuchElementException as e:
    duration.append("-")
            
#Extracting stops
try:
    Total_Stops = driver.find_elements_by_xpath("//div[@class=' font-lightgrey fs-10 tipsy i-b fs-10']")
    for i in Total_Stops:
        total_stop.append(i.text)
        
except NoSuchElementException as e:
    total_stop.append("-")
            

#Extracting price of the ticket
try:
    pr = driver.find_elements_by_xpath("//div[@class='i-b tipsy fare-summary-tooltip fs-18']")
    for i in pr:
        price.append(i.text)
        
except NoSuchElementException as e:
    price.append("-")

# %%
#show calender 
calender = driver.find_element_by_xpath("//p[@class = 'bold font-lightgrey fs-8 mt-2 text-uppercase']")
calender.click()

next_day = driver.find_element_by_xpath("//td[@class=' shown'][2]")
next_day.click()

# %%
#Extracting airlines name
try:
    Name = driver.find_elements_by_xpath("//span[@class='i-b text ellipsis']")
    for i in Name:
        Airline_Name.append(i.text)
        
except NoSuchElementException as e:
    Airline_Name.append("-")
            
#Extracting departure time
try:
    DTime = driver.find_elements_by_xpath("//div[@class='fs-15 bold time']")
    for i in DTime:
        Departure_time.append(i.text)
        
except NoSuchElementException as e:
    Departure_time.append("-")
    
#Extracting arival time
try:
    atime = driver.find_elements_by_xpath("//p[@class='bold fs-15 mb-2 pr time']")
    for i in atime:
        arrival_time.append(i.text)
        
except NoSuchElementException as e:
    arrival_time.append("-")

#Extracting source
try:
    Source = driver.find_elements_by_xpath("//p[@class='fs-10 font-lightgrey no-wrap city ellipsis']")
    for i in Source:
        source.append(i.text)
        
except NoSuchElementException as e:
    source.append("-")
            

#Extracting duration
try:
    Duration = driver.find_elements_by_xpath("//p[@class='fs-12 bold du mb-2']")
    for i in Duration:
        duration.append(i.text)
        
except NoSuchElementException as e:
    duration.append("-")
            
#Extracting stops
try:
    Total_Stops = driver.find_elements_by_xpath("//div[@class=' font-lightgrey fs-10 tipsy i-b fs-10']")
    for i in Total_Stops:
        total_stop.append(i.text)
        
except NoSuchElementException as e:
    total_stop.append("-")
            

#Extracting price of the ticket
try:
    pr = driver.find_elements_by_xpath("//div[@class='i-b tipsy fare-summary-tooltip fs-18']")
    for i in pr:
        price.append(i.text)
        
except NoSuchElementException as e:
    price.append("-")

# %%
for i in range(0,len(source),2):
    SOURCE.append(source[i])


for i in range(1,len(source),2):
    destination.append(source[i])

# %%
#Extracting date of journey
Date = [29]*25
Date[26:50] = [28]*25
Date[51:75] = [30]*25
Date[76:100] = [30]*25
Date[101:121] = [28]*21
Date[122:146] = [29]*25
Date[147:171] = [29]*25
Date[171:178] = [28]*7
Date[179:203] = [30]*25
Date[203:228] = [29]*25
Date[229:253] = [28]*25
Date[254:278] = [30]*25
Date[279:303] = [30]*25
Date[304:328] = [28]*25
Date[329:353] = [29]*25
Date[354:378] = [29]*25
Date[378:403] = [28]*25
Date[403:453] = [30]*50
Date[454:478] = [30]*25
Date[478:500] = [28]*22
Date[500:525] = [29]*25

Month = [11]*525
Year = [2021]*525

# %%
Airline_Name
len(Airline_Name)
# Out:
# 525

# %%
len(Date)
# Out:
# 525

# %%
price
len(price)
# Out:
# 525

# %%
total_stop
len(total_stop)
# Out:
# 525

# %%
duration
len(duration)
# Out:
# 525

# %%
destination
len(destination)
# Out:
# 525

# %%
SOURCE
len(SOURCE)
# Out:
# 525

# %%
source
len(source)
# Out:
# 1050

# %%
arrival_time
len(arrival_time)
# Out:
# 525

# %%
Departure_time
len(Departure_time)
# Out:
# 525

# %%
len(Date)
# Out:
# 525

# %%
flights = pd.DataFrame({})
flights['AIRLINE NAME '] = Airline_Name
flights['SOURCE'] = SOURCE
flights['DESTINATIION'] = destination
flights['DEPARTURE TIME'] = Departure_time
flights['ARRIVAL TIME'] = arrival_time
flights['DATE'] = Date
flights['MONTH'] = Month
flights['YEAR'] = Year
flights['DURATION'] = duration
flights['TOTAL STOPS'] = total_stop
flights['PRICE'] = price
flights
# Out:
#     AIRLINE NAME      SOURCE DESTINATIION DEPARTURE TIME    ARRIVAL TIME  \
# 0        SpiceJet  New Delhi       Mumbai          19:00  10:35\n+ 1 day
# 1        Air Asia  New Delhi       Mumbai          20:00  02:25\n+ 1 day
# 2        Air Asia  New Delhi       Mumbai          20:45  07:15\n+ 1 day
# 3        Air Asia  New Delhi       Mumbai          12:40  02:25\n+ 1 day
# 4        Air Asia  New Delhi       Mumbai          12:10  02:25\n+ 1 day
# ..            ...        ...          ...            ...             ...
# 520     Air India  Hyderabad          Goa          22:15  22:25\n+ 1 day
# 521       Vistara  Hyderabad          Goa          21:35  07:50\n+ 1 day
# 522       Vistara  Hyderabad          Goa          21:35  12:45\n+ 1 day
# 523     Air India  Hyderabad          Goa          14:00           20:30
# 524     Air India  Hyderabad          Goa          22:15  20:30\n+ 1 day
#
#      DATE  MONTH  YEAR DURATION TOTAL STOPS  PRICE
# ...

# %%
#Saving in a csv file
flights.to_csv('flights_data.csv')

# %%
pd.read_csv('flights_data.csv')
# Out:
#      Unnamed: 0 AIRLINE NAME      SOURCE DESTINATIION DEPARTURE TIME  \
# 0             0      SpiceJet  New Delhi       Mumbai          19:00
# 1             1      Air Asia  New Delhi       Mumbai          20:00
# 2             2      Air Asia  New Delhi       Mumbai          20:45
# 3             3      Air Asia  New Delhi       Mumbai          12:40
# 4             4      Air Asia  New Delhi       Mumbai          12:10
# ..          ...           ...        ...          ...            ...
# 520         520     Air India  Hyderabad          Goa          22:15
# 521         521       Vistara  Hyderabad          Goa          21:35
# 522         522       Vistara  Hyderabad          Goa          21:35
# 523         523     Air India  Hyderabad          Goa          14:00
# 524         524     Air India  Hyderabad          Goa          22:15
#
#        ARRIVAL TIME  DATE  MONTH  YEAR DURATION TOTAL STOPS  PRICE
# 0    10:35\n+ 1 day    29     11  2021  15h 35m      1 Stop  5,635
# ...
